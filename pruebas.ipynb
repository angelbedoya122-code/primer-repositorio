# %%
def saludar(nombre):
    print('Hola', nombre)

# %%
saludar("Pablocholito")
# Out:
# Hola Pablocholito

# %%
def primo(n):
    cont = 0
    for i in range(2,n):
        if n%i==0:
            cont += 1
    if cont > 0:
        return False
    return True

# %%
for i in [23, 5, 7, 11, 9]:
    print(primo(i))
# Out:
# True
# True
# True
# True
# False
